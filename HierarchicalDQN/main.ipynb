# %%
import sys,os
from pathlib import Path
curr_path = str(Path().absolute())
parent_path = str(Path().absolute().parent)
sys.path.append(parent_path) # add current terminal path to sys.path

import gym
import torch
import numpy as np
import datetime

from HierarchicalDQN.agent import HierarchicalDQN
from common.plot import plot_rewards
from common.utils import save_results

# %%
SEQUENCE = datetime.datetime.now().strftime(
    "%Y%m%d-%H%M%S")  # obtain current time
SAVED_MODEL_PATH = curr_path+"/saved_model/"+SEQUENCE+'/'  # path to save model
if not os.path.exists(curr_path+"/saved_model/"):
    os.mkdir(curr_path+"/saved_model/")
if not os.path.exists(SAVED_MODEL_PATH):
    os.mkdir(SAVED_MODEL_PATH)
RESULT_PATH = curr_path+"/results/"+SEQUENCE+'/'  # path to save rewards
if not os.path.exists(curr_path+"/results/"):
    os.mkdir(curr_path+"/results/")
if not os.path.exists(RESULT_PATH):
    os.mkdir(RESULT_PATH)

# %%
class HierarchicalDQNConfig:
    def __init__(self):
        self.algo = "H-DQN"  # name of algo
        self.gamma = 0.95
        self.epsilon_start = 1  # start epsilon of e-greedy policy
        self.epsilon_end = 0.01
        self.epsilon_decay = 500
        self.lr = 0.0001  # learning rate
        self.memory_capacity = 20000  # Replay Memory capacity
        self.batch_size = 64
        self.train_eps = 300  # 训练的episode数目
        self.target_update = 2  # target net的更新频率
        self.eval_eps = 20  # 测试的episode数目
        self.device = torch.device(
            "cuda" if torch.cuda.is_available() else "cpu")  # 检测gpu
        self.hidden_dim = 256  # dimension of hidden layer

# %%
def train(cfg, env, agent):
    print('Start to train !')
    rewards = []
    ma_rewards = []  # moveing average reward
    for i_episode in range(cfg.train_eps):
        state = env.reset()
        done = False
        ep_reward = 0
        while not done:
            goal = agent.set_goal(state)
            onehot_goal = agent.to_onehot(goal)
            meta_state = state
            extrinsic_reward = 0
            while not done and goal != np.argmax(state):
                goal_state = np.concatenate([state, onehot_goal])
                action = agent.choose_action(goal_state)
                next_state, reward, done, _ = env.step(action)
                ep_reward += reward
                extrinsic_reward += reward
                intrinsic_reward = 1.0 if goal == np.argmax(
                    next_state) else 0.0
                agent.memory.push(goal_state, action, intrinsic_reward, np.concatenate(
                    [next_state, onehot_goal]), done)
                state = next_state
                agent.update()
        agent.meta_memory.push(meta_state, goal, extrinsic_reward, state, done)
        print('Episode:{}/{}, Reward:{}'.format(i_episode+1, cfg.train_eps, ep_reward))
        rewards.append(ep_reward)
        if ma_rewards:
            ma_rewards.append(
                0.9*ma_rewards[-1]+0.1*ep_reward)
        else:
            ma_rewards.append(ep_reward)
    print('Complete training！')
    return rewards, ma_rewards

# %%
env = gym.make('CartPole-v0')
env.seed(1)
cfg = HierarchicalDQNConfig()
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
agent = HierarchicalDQN(state_dim, action_dim, cfg)
rewards, ma_rewards = train(cfg, env, agent)
agent.save(path=SAVED_MODEL_PATH)
save_results(rewards, ma_rewards, tag='train', path=RESULT_PATH)
plot_rewards(rewards, ma_rewards, tag="train",
                algo=cfg.algo, path=RESULT_PATH)
# Out:
# Start to train !
# Episode:1/300, Reward:20.0
# Episode:2/300, Reward:17.0
# Episode:3/300, Reward:14.0
# Episode:4/300, Reward:40.0
# Episode:5/300, Reward:32.0
# Episode:6/300, Reward:41.0
# Episode:7/300, Reward:12.0
# Episode:8/300, Reward:17.0
# Episode:9/300, Reward:19.0
# Episode:10/300, Reward:13.0
# Episode:205/300, Reward:107.0
# Episode:206/300, Reward:104.0
# Episode:207/300, Reward:127.0
# Episode:208/300, Reward:137.0
# Episode:209/300, Reward:124.0
# Episode:210/300, Reward:117.0
# Episode:211/300, Reward:123.0
# Episode:212/300, Reward:184.0
# Episode:213/300, Reward:134.0
# Episode:214/300, Reward:115.0
# Episode:215/300, Reward:118.0
# Episode:216/300, Reward:55.0
# Episode:217/300, Reward:133.0
# Episode:218/300, Reward:101.0
# Episode:219/300, Reward:47.0
# Episode:220/300, Reward:163.0
# Episode:221/300, Reward:200.0
# Episode:222/300, Reward:200.0
# Episode:223/300, Reward:200.0
# Episode:224/300, Reward:200.0
# Episode:225/300, Reward:200.0
# Episode:226/300, Reward:143.0
# Episode:227/300, Reward:140.0
# Episode:228/300, Reward:119.0
# Episode:229/300, Reward:126.0
# Episode:230/300, Reward:120.0
# Episode:231/300, Reward:132.0
# Episode:232/300, Reward:145.0
# Episode:233/300, Reward:200.0
# Episode:234/300, Reward:153.0
# Episode:235/300, Reward:156.0
# Episode:236/300, Reward:146.0
# Episode:237/300, Reward:167.0
# Episode:238/300, Reward:200.0
# Episode:239/300, Reward:200.0
# Episode:240/300, Reward:200.0
# Episode:241/300, Reward:147.0
# Episode:242/300, Reward:126.0
# Episode:243/300, Reward:119.0
# Episode:244/300, Reward:117.0
# Episode:245/300, Reward:114.0
# Episode:246/300, Reward:120.0
# Episode:247/300, Reward:200.0
# Episode:248/300, Reward:142.0
# Episode:249/300, Reward:157.0
# Episode:250/300, Reward:124.0
# Episode:251/300, Reward:128.0
# Episode:252/300, Reward:138.0
# Episode:253/300, Reward:142.0
# Episode:254/300, Reward:200.0
# Episode:255/300, Reward:200.0
# Episode:256/300, Reward:149.0
# Episode:257/300, Reward:176.0
# Episode:258/300, Reward:155.0
# Episode:259/300, Reward:200.0
# Episode:260/300, Reward:200.0
# Episode:261/300, Reward:165.0
# Episode:262/300, Reward:200.0
# Episode:263/300, Reward:137.0
# Episode:264/300, Reward:200.0
# Episode:265/300, Reward:200.0
# Episode:266/300, Reward:92.0
# Episode:267/300, Reward:45.0
# Episode:268/300, Reward:14.0
# Episode:269/300, Reward:26.0
# Episode:270/300, Reward:18.0
# Episode:271/300, Reward:15.0
# Episode:272/300, Reward:13.0
# Episode:273/300, Reward:13.0
# Episode:274/300, Reward:12.0
# Episode:275/300, Reward:10.0
# Episode:276/300, Reward:31.0
# Episode:277/300, Reward:13.0
# Episode:278/300, Reward:12.0
# Episode:279/300, Reward:28.0
# Episode:280/300, Reward:27.0
# Episode:281/300, Reward:11.0
# Episode:282/300, Reward:12.0
# Episode:283/300, Reward:9.0
# Episode:284/300, Reward:9.0
# Episode:285/300, Reward:12.0
# Episode:286/300, Reward:11.0
# Episode:287/300, Reward:9.0
# Episode:288/300, Reward:11.0
# Episode:289/300, Reward:13.0
# Episode:290/300, Reward:12.0
# Episode:291/300, Reward:14.0
# Episode:292/300, Reward:10.0
# Episode:293/300, Reward:12.0
# Episode:294/300, Reward:100.0
# Episode:295/300, Reward:128.0
# Episode:296/300, Reward:200.0
# Episode:297/300, Reward:200.0
# Episode:298/300, Reward:10.0
# Episode:299/300, Reward:9.0
# Episode:300/300, Reward:9.0
# Complete training！
# results saved!
